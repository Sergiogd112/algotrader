# %%
import urllib3
import json
import pickle as pk
import time
from bs4 import BeautifulSoup
import datetime
import dateutil.relativedelta as dr
import pandas as pd
from urllib import request
token='d8Xmkk0xAAeEbWUEDR006rRWWc279ohzXTe6ztVNARXxVChelFDA1EhQxdH9'

# %%
http = urllib3.PoolManager()
symbol='AAPL.MI'
ihurl="https://intraday.worldtradingdata.com/api/v1/intraday?symbol="+symbol+"&interval=5&range=1&api_token="+token

# %%
json.loads(http.request('GET', ihurl).data)
# Out:
# {'symbol': 'AAPL.MI',
#  'stock_exchange_short': 'MTA',
#  'timezone_name': 'Europe/Rome',
#  'intraday': {'2020-03-13 17:25:00': {'open': '232.55',
#    'close': '231.55',
#    'high': '232.55',
#    'low': '231.55',
#    'volume': '20'},
#   '2020-03-13 17:20:00': {'open': '231.20',
#    'close': '231.30',
#    'high': '231.30',
#    'low': '231.20',
#    'volume': '25'},
#   '2020-03-13 17:15:00': {'open': '232.05',
#    'close': '232.05',
#    'high': '232.05',
#    'low': '232.05',
#    'volume': '81'},
#   '2020-03-13 17:10:00': {'open': '232.05',
#    'close': '232.05',
#    'high': '232.05',
#    'low': '232.05',
#    'volume': '81'},
#   '2020-03-13 17:05:00': {'open': '231.00',
#    'close': '231.00',
#    'high': '231.00',
#    'low': '231.00',
#    'volume': '10'},
#   '2020-03-13 17:00:00': {'open': '231.00',
#    'close': '231.00',
#    'high': '231.00',
#    'low': '231.00',
#    'volume': '10'},
#   '2020-03-13 16:55:00': {'open': '232.65',
#    'close': '232.65',
# ...
